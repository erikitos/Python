# %% [markdown]
# <a href="https://colab.research.google.com/github/erikitos/Python/blob/main/DIA_3_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DIA 3
#
# #TEMARIO
# - Listas
# - Tuplas
# - Sets
# - Diccionarios

# %% [markdown]
# # Estructuras De Datos
# Las estructuras de datos son formas de organizar informacion para trabajar con ella de manera eficiente.
#
# - listas -->
# ordenadas, modificables , permiten duplicados.
# - Tuplas -->
# ordenadas , inmutables , permiten duplicados.
# - Sets --> no ordenados , sin duplicados .
# -  Diccionarios -->
# pares clave: valor.
#
# Nota:
# - Pilas ( FILO -> First in ,Last out )
# - Colas(FIFO -> First in , First out)
# - Listas enlazadas ( o doblemente enlazadas)

# %% [markdown]
# # LISTAS
# Las listas son colecciones ordenadas que podemos modificar y almacenan   elementos de distintos tipos de datos.

# %%
Lista_de_compras = ["manzanas", "pan" ,"leche" ,"huevos" , "mantequilla " , "queso" , "jamon"]
print(Lista_de_compras)
# Out:
# ['manzanas', 'pan', 'leche', 'huevos', 'mantequilla ', 'queso', 'jamon']

# %%
print(Lista_de_compras[6])
# Out:
# jamon

# %%
# Agregar un elemento a la lista .append()
Lista_de_compras.append("sopa")
print(Lista_de_compras)  #Imprime la lista con "sopa" al final
# Out:
# ['manzanas', 'pan', 'leche', 'huevos', 'mantequilla ', 'queso', 'jamon', 'sopa']

# %%
# Agregar un elemento en una posicion especifica
Lista_de_compras.insert(1,"platano")
Lista_de_compras
# Out:
# ['manzanas',
#  'platano',
#  'platano',
#  'pan',
#  'leche',
#  'huevos',
#  'mantequilla ',
#  'queso',
#  'jamon',
#  'sopa']

# %%
print(Lista_de_compras)
# Out:
# ['manzanas', 'platano', 'platano', 'pan', 'leche', 'huevos', 'mantequilla ', 'queso', 'jamon', 'sopa']

# %%
# Para eliminar un elemento de una lista existe el remove y el pop
Lista_de_compras.remove("platano")
print(Lista_de_compras)
# Out:
# ['manzanas', 'platano', 'pan', 'leche', 'huevos', 'mantequilla ', 'queso', 'jamon', 'sopa']

# %%
Lista_de_compras.pop() # Sin nada dentro del parentesis elimina el ultimo elemento de la lista
Lista_de_compras.pop(7) # O puedes agarrarla desde la posicion que  quieras(pero iniciando desde 0)
# Out:
# 'jamon'

# %%
# Podemos recorrer el arreglo por medio de un for
for elemento in Lista_de_compras:
  print(elemento)
# Out:
# manzanas
# platano
# pan
# leche
# huevos
# mantequilla
# queso

# %%
# len() saca el tamaño de la lista
print(len(Lista_de_compras))
for i in range(len(Lista_de_compras)):
  print(f"{i+1} - {Lista_de_compras[i]}")
# Out:
# 7
# 1 - manzanas
# 2 - platano
# 3 - pan
# 4 - leche
# 5 - huevos
# 6 - mantequilla
# 7 - queso

# %%
# Opcional
import random
opciones = ["piedra", "papel", "tijeras"]

while True:
    while True:
        eleccion = input("\nElige piedra, papel o tijeras (o escribe salir si ya no quieres jugar): ")
        if eleccion not in opciones and not eleccion == "salir":
            print("Opción no válida, intenta de nuevo.")
        else:
            break

    if eleccion == "salir":
        print("¡Gracias por jugar!")
        break
    aleatoria = random.choice(opciones)
    print("La computadora eligió:", aleatoria)

    # Determinamos el ganador
    if eleccion == aleatoria:
        print("Empate")
    elif (eleccion == "piedra" and aleatoria == "tijeras") \
        or (eleccion == "papel" and aleatoria == "piedra") \
        or (eleccion == "tijeras" and aleatoria == "papel"):
        print("¡Ganaste! :)")
    else:
        print("Perdiste :(")
# Out:
# Elige piedra, papel o tijeras (o escribe salir si ya no quieres jugar): papel
# La computadora eligió: tijeras
# Perdiste :(
#
# Elige piedra, papel o tijeras (o escribe salir si ya no quieres jugar): piedra
# La computadora eligió: piedra
# Empate
#
# Elige piedra, papel o tijeras (o escribe salir si ya no quieres jugar): piedra
# La computadora eligió: papel
# Perdiste :(
#
# Elige piedra, papel o tijeras (o escribe salir si ya no quieres jugar): tijeras
# La computadora eligió: tijeras
# Empate
#
# Elige piedra, papel o tijeras (o escribe salir si ya no quieres jugar): piedra
# La computadora eligió: papel
# Perdiste :(
#
# Elige piedra, papel o tijeras (o escribe salir si ya no quieres jugar): tijeras
# La computadora eligió: papel
# ¡Ganaste! :)
#
# Elige piedra, papel o tijeras (o escribe salir si ya no quieres jugar): salir
# ¡Gracias por jugar!

# %%
promedios =[55.6,97.5,23.6,97.5,72.4,100]
print(promedios)
promedios.sort() # Sirve para ordenar la lista de manera ascendente
print(promedios)

# Ordenar una lista de manera descendente
promedios.sort(reverse=True)
print(promedios)
# Out:
# [55.6, 97.5, 23.6, 97.5, 72.4, 100]
# [23.6, 55.6, 72.4, 97.5, 97.5, 100]
# [100, 97.5, 97.5, 72.4, 55.6, 23.6]

# %%
# Podemos agregar al ultimo elemento de una lista
print(promedios [-1])
# Out:
# 23.6

# %%
 # Encontrar el mayor y menor de una lista
 print(max(promedios))
 print(min(promedios))
# Out:
# 100
# 23.6

# %%
# Declaracion y uso de matrices
calificaciones = [[100,88,93], [99,56,72]]
i = 1
for cali_i in calificaciones:
  print(f"\nAlumno {i}")
  j = 1
  for cali_j in cali_i:
    print(f" Cali {j}: {cali_j}") # Corrected f-string syntax
    j += 1
  i += 1 # Corrected indentation for i increment
# Out:
# Alumno 1
#  Cali 1: 100
#  Cali 2: 88
#  Cali 3: 93
#
# Alumno 2
#  Cali 1: 99
#  Cali 2: 56
#  Cali 3: 72

# %% [markdown]
#  ## Tuplas
# Colecciones ordenadas pero inmutables

# %%
# Hagamos un donde guardemos fechas de nacimiento de un grupo en una tupla
fechas = ("10/10/05," , "22/03/02" , "17/04/04" , "25/02/04")
print(type(fechas))
fechas
# Out:
# <class 'tuple'>
# ('10/10/05,', '22/03/02', '17/04/04', '25/02/04')

# %%
# ES INMUTABLE
fechas.append("10/06/03") # TE VA A MARCAR ERROR
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-442830669.py in <cell line: 0>()
#       1 # ES INMUTABLE
# ----> 2 fechas.append("10/06/03") # TE VA A MARCAR ERROR
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
fechas_lista = list(fechas) # Aqui ya puedes usar los comentarios basicos de una lista

# %% [markdown]
# ## SETS
# Los sets son colecciones SIN orden y que NO permiten elementos duplicados

# %%
nombre = {" Angel", "Eliud" , "Diana" , "Juan" , "Juan"}
print(nombre)
print(type(nombre))
# Out:
# {'Eliud', 'Juan', 'Diana', ' Angel'}
# <class 'set'>

# %%
distintos_datos = {" Angel", 1, "Diana" , "Juan" ,"Juan", 4.8}
distintos_datos
# Out:
# {' Angel', 1, 4.8, 'Diana', 'Juan'}

# %%
# Add
nombre.add("leonardo")
nombre
# Out:
# {' Angel', 'Diana', 'Eliud', 'Juan', 'leonardo'}

# %%
print(nombre[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1064476624.py in <cell line: 0>()
# ----> 1 print(nombre[2])
#
# TypeError: 'set' object is not subscriptable

# %%
nombre[2] =Axel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1047566360.py in <cell line: 0>()
# ----> 1 nombre[2] =Axel
#
# NameError: name 'Axel' is not defined

# %%
# Union
matutino = {20322,22183,123123,53234}
vespertino = {20322,111111,222222222,3333333}
total_matriculas = matutino.union(vespertino)
print(total_matriculas)
total_matriculas = matutino | vespertino
print(total_matriculas)
# Out:
# {20322, 22183, 111111, 222222222, 53234, 123123, 3333333}
# {20322, 22183, 111111, 222222222, 53234, 123123, 3333333}

# %%
# Interseccion
ca = {1234,121,646,12414,73434,124124,675234}
al = {1234,111,222,333,444}
#interseccion con .intersection()
ca_al = ca.intersection(al)
print(ca_al)
# interseccion usando &
ca_al = ca & al
print(ca_al)
# Out:
# {1234}
# {1234}

# %%
# Diferencia
# Diferencia usando ,difference
solo_calculo = ca.difference(al)
print(solo_calculo)
# Diferencia usando -
solo_calculo = ca - al
print(solo_calculo)
# Out:
# {675234, 646, 121, 73434, 124124, 12414}
# {675234, 646, 121, 73434, 124124, 12414}

# %%
nombre = {" Angel", "Eliud" , "Diana" , "Juan" , "Juan"}
#remove , pop
#nombre.remove("Angel") #Puedes eliminar el  que tu quieras
print(nombre)
nombre.pop() #Elimina un elemento de manera aleatoria
print(nombre)
# Out:
# {'Eliud', 'Juan', 'Diana', ' Angel'}
# {'Juan', 'Diana', ' Angel'}

# %%
# Eliminar todo el SET
nombre.clear()
nombre
# Out:
# set()

# %% [markdown]
# ## Diccionarios
# los diccionarios son colecciones no ordenadas de pares clave:valor

# %%
alumno = {
    "nombre": "Erik De La Cruz Ramos",
    "edad": 19 ,
    "carrera": "IMTC",
    "Semestre": 2,
    "Promedio": 93,
    "Calificaciones": [100,94,94,97,100]
}
print(type(alumno))
alumno
# Out:
# <class 'dict'>
# {'nombre': 'Erik De La Cruz Ramos',
#  'edad': 19,
#  'carrera': 'IMTC',
#  'Semestre': 2,
#  'Promedio': 93,
#  'Calificaciones': [100, 94, 94, 97, 100]}

# %%
print("el alumno",alumno["nombre"],"esta estudiando",alumno["carrera"])
# Out:
# el alumno Erik De La Cruz Ramos esta estudiando IMTC

# %%
# Agregar al diccionario
alumno["area preferida"] =  " Ciencia de Datos"
alumno
# Out:
# {'nombre': 'Erik De La Cruz Ramos',
#  'edad': 19,
#  'carrera': 'IMTC',
#  'Semestre': 2,
#  'Promedio': 93,
#  'Calificaciones': [100, 94, 94, 97, 100],
#  'area preferida': ' Ciencia de Datos'}

# %%
for valor in alumno:
  print(alumno [valor])
# Out:
# Erik De La Cruz Ramos
# 19
# IMTC
# 2
# 93
# [100, 94, 94, 97, 100]
#  Ciencia de Datos

# %%
for aspecto,valor in alumno.items(): # Devuelve una vista de todos los pares clave :valor del diccionario
  print(aspecto,":", valor)
# Out:
# nombre : Erik De La Cruz Ramos
# edad : 19
# carrera : IMTC
# Semestre : 2
# Promedio : 93
# Calificaciones : [100, 94, 94, 97, 100]
# area preferida :  Ciencia de Datos

# %%
# El metodo .clear() tambien usar aqui.
# Tenemos el .get que nos ayuda a obtener el valor (value) de cierta clave (key)
print(alumno.get("nombre"))
# Out:
# Erik De La Cruz Ramos

# %%
alumno_1 = alumno.items()
print(alumno_1)
print(type(alumno_1))
alumno_lista = list(alumno_1)
print(alumno_lista)
print(type(alumno_lista))
# Out:
# dict_items([('nombre', 'Erik De La Cruz Ramos'), ('edad', 19), ('carrera', 'IMTC'), ('Semestre', 2), ('Promedio', 93), ('Calificaciones', [100, 94, 94, 97, 100]), ('area preferida', ' Ciencia de Datos')])
# <class 'dict_items'>
# [('nombre', 'Erik De La Cruz Ramos'), ('edad', 19), ('carrera', 'IMTC'), ('Semestre', 2), ('Promedio', 93), ('Calificaciones', [100, 94, 94, 97, 100]), ('area preferida', ' Ciencia de Datos')]
# <class 'list'>

# %%
# El metodo .values() sirve para obtener los valores del diccionario , tambien se puede usar en la interaccion
alumno_v = alumno.values()
print(type(alumno_v))
alumno_v
# Out:
# <class 'dict_values'>
# dict_values(['Erik De La Cruz Ramos', 19, 'IMTC', 2, 93, [100, 94, 94, 97, 100], ' Ciencia de Datos'])

# %%
if "carrera" in alumno:
    print("Existe la carrera")
else:
    print("No existe la carrera")

if "dinero" in alumno:
    print("Alumno tiene dinero")
else:
    print("Alumno no tiene dinero")
# Out:
# Existe la carrera
# Alumno no tiene dinero

# %%
#.copy() puedes copiar todo el diccionario en una nueva variable
# Update -> Sirve para cambiar los values (valores) (.update())
alumno.update({"semestre":1})
alumno
# Out:
# {'nombre': 'Erik De La Cruz Ramos',
#  'edad': 19,
#  'carrera': 'IMTC',
#  'Semestre': 2,
#  'Promedio': 93,
#  'Calificaciones': [100, 94, 94, 97, 100],
#  'area preferida': ' Ciencia de Datos',
#  'semestre': 1}

# %%
# Lista de productos
productos = ["manzana", "banana", "leche", "pan"]  # <-- LISTA

# Tupla de precios
precios = (10, 5, 20, 15)  # <-- TUPLA

# Diccionario de inventario: producto -> {"precio": x, "stock": y}
inventario = {productos[i]: {"precio": precios[i], "stock": 10} for i in range(len(productos))}
# <-- DICCIONARIO
# Clave: nombre del producto
# Valor: otro diccionario con "precio" y "stock"

# Set de productos en oferta
ofertas = {"manzana", "pan"}  # <-- SET

# Mostrar productos
for p in productos:
    msg = "OFERTA!!!" if p in ofertas else "Grandes precios!"
    info = inventario[p]
    print(f"{p.title()} - ${info['precio']} - Stock: {info['stock']} -> {msg}")

# Compra simple
compra = input("\n¿Qué producto quieres comprar? ").strip().lower()
if compra in inventario and inventario[compra]["stock"] > 0:
    inventario[compra]["stock"] -= 1
    print(f"Compraste 1 {compra}. Stock restante: {inventario[compra]['stock']}")
else:
    print("Producto no disponible.")
# Out:
# Manzana - $10 - Stock: 10 -> OFERTA!!!
# Banana - $5 - Stock: 10 -> Grandes precios!
# Leche - $20 - Stock: 10 -> Grandes precios!
# Pan - $15 - Stock: 10 -> OFERTA!!!
#
# ¿Qué producto quieres comprar? manzana
# Compraste 1 manzana. Stock restante: 9
